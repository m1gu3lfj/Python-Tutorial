# %% [markdown]
# # 10 Entrada por teclado en Python
#
# ---

# %% [markdown]
# ## 10.1 Entrada por teclado

# %% [markdown]
# Python permite la entrada estándar de datos (por teclado), para ello utilizaremos la finción `input()`.
#
# Cuando se ejecuta la función input se detiene la ejecucción de Python hasta que se introduce por teclado la cadena correspondiente.

# %%
nombre = input("Introduce nombre usuario:")
print("El nombre usuario es: " + nombre)
# Out:
# Introduce nombre usuario:abc1234
# El nombre usuario es: abc1234
